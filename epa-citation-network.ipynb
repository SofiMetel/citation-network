# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re
import numpy as np

# %% [markdown]
# Terminology:
#
# Source publication (or source) is the EPA funded research that was chosen to scrape citation from.
# Target is citation that are used in source publication ( that is extracted from source)
#
# Direct graph. From each source node should be the same amount of edges to target nodes as items in the reference list in each source publication
#
# **Source -> Target**

# %% [markdown]
# ##Part 1: Web-scraping of publications info from epa website

# %% [markdown]
# BeautifulSoup was used to gather links to pdf and publication titles. Other metadata also were gathered but not used.

# %%
pub_title=[]
pub_link =[]
year = []
ISBN =[]
pages=[]
filesize  = []
format = []
research_num = []

# %% [markdown]
# I wanted to have more control over what publication from epa website will be scraped so I  chose manually publications and added its link to this part.
# In future it can be rewritten to automatic scrape of everythong with 'Research' in the beginning.

# %%
epa_urls = [ 'https://www.epa.ie/publications/research/environment--health/research-259.php',
             'https://www.epa.ie/publications/research/climate-change/research-346-national-risk-assessment-of-impacts-of-climate-change.php',
             'https://www.epa.ie/publications/research/climate-change/research-429-building-coastal-and-marine-resilience-in-ireland.php',
             'https://www.epa.ie/publications/research/climate-change/research-369.php',
             'https://www.epa.ie/publications/research/climate-change/research-362-evaluating-irelands-climate-policy-performance.php',
             'https://www.epa.ie/publications/research/climate-change/research-360-methodologies-for-financing-and-costing-of-climate-impacts-and-future-adaptation-actions-transport-networks-in-ireland.php',
             'https://www.epa.ie/publications/research/climate-change/research-357-irelands-atmospheric-composition-and-climate-change-network.php',
             'https://www.epa.ie/publications/research/climate-change/research-352-synthesis-of-literature-and-preliminary-modelling-relevant-to-society-wide-scenarios-for-effective-climate-change-mitigation-in-ireland.php'
]

# %%
'''
epa_urls is a list of publication link on epa website
'''
#just to check if it works
for i in range(len(epa_urls)):
  print(epa_urls[i])
# Out:
# https://www.epa.ie/publications/research/environment--health/research-259.php
# https://www.epa.ie/publications/research/climate-change/research-346-national-risk-assessment-of-impacts-of-climate-change.php
# https://www.epa.ie/publications/research/climate-change/research-429-building-coastal-and-marine-resilience-in-ireland.php
# https://www.epa.ie/publications/research/climate-change/research-369.php
# https://www.epa.ie/publications/research/climate-change/research-362-evaluating-irelands-climate-policy-performance.php
# https://www.epa.ie/publications/research/climate-change/research-360-methodologies-for-financing-and-costing-of-climate-impacts-and-future-adaptation-actions-transport-networks-in-ireland.php
# https://www.epa.ie/publications/research/climate-change/research-357-irelands-atmospheric-composition-and-climate-change-network.php
# https://www.epa.ie/publications/research/climate-change/research-352-synthesis-of-literature-and-preliminary-modelling-relevant-to-society-wide-scenarios-for-effective-climate-change-mitigation-in-ireland.php

# %%
'''
Web-scraping from epa website
Code extracts year, ISBN, pages, filesizes, format, title and authors of each publications and saves to previously defined lists.

'''

for i in range(len(epa_urls)):
  epa_url = epa_urls[i]

  # Use requests to retrieve data from a given URL
  epa_response = requests.get(epa_url)
  # Parse the whole HTML page using BeautifulSoup
  epa_soup = BeautifulSoup(epa_response.text, 'html.parser')
  publication_title = [h.text for h in epa_soup.find_all("h2", attrs={"class": "publications__title"})]
  for i in publication_title:
    research =  i.split(': ',1)
    pub_title.append(research[1])
    research_num.append(research[0])



  pub_info=epa_soup.find_all("div", attrs={"class": "publications__panel__content"})
  # Find link to download
  publication_link = [link.get('href') for link in epa_soup.find_all('a', attrs={"aria-label": "Download this publication"})]
  pub_link.append(publication_link[0])


  table = [data.text for data in epa_soup.find_all("div", attrs={"class": "publications__panel__content"})]

  mylist = table[0].split('\n')[1:-4]

  mylist=[mylist[i].split(': ') for i in range(len(mylist))]

  year.append(mylist[0][1])
  ISBN.append(mylist[1][1])
  pages.append(mylist[2][1])
  filesize.append(mylist[3][1])
  format.append(mylist[4][1])

# %%
pub_title
# Out:
# ['Detection, Toxicology, Environmental Fate and Risk Assessment of Nanoparticles in the Aquatic Environment (DeTER)',
#  'National Risk Assessment of Impacts of Climate Change: Bridging the Gap to Adaptation Action',
#  'Building Coastal and Marine Resilience in Ireland',
#  'CIViC: Critical Infrastructure Vulnerability to Climate Change',
#  'Evaluating Ireland’s Climate Policy Performance',
#  'Methodologies for Financing and Costing of Climate Impacts and Future Adaptation Actions: Transport Networks in Ireland',
#  'Ireland’s Atmospheric Composition and Climate Change Network',
#  'Synthesis of Literature and Preliminary Modelling Relevant to Society-wide Scenarios for Effective Climate Change Mitigation in Ireland']

# %%
pub_link
# Out:
# ['https://www.epa.ie/publications/research/environment--health/Research_Report_259.pdf',
#  'https://www.epa.ie/publications/research/climate-change/Research_Report_346.pdf',
#  'https://www.epa.ie/publications/research/climate-change/Research_Report_429.pdf',
#  'https://www.epa.ie/publications/research/climate-change/Research_Report_369.pdf',
#  'https://www.epa.ie/publications/research/climate-change/Research_Report_362.pdf',
#  'https://www.epa.ie/publications/research/climate-change/Research_Report_360.pdf',
#  'https://www.epa.ie/publications/research/climate-change/Research_Report_357.pdf',
#  'https://www.epa.ie/publications/research/climate-change/Research_Report_352.pdf']

# %%
'''
Pandas DataFrame will be transformed from dictionary
'''

mydict = dict({'title': pub_title,
               'research_number': research_num,
               'year': year,
               'ISBN': ISBN,
               'filesize': filesize,
               'format': format,
               'link': pub_link
               })

print(mydict)
# Out:
# {'title': ['Detection, Toxicology, Environmental Fate and Risk Assessment of Nanoparticles in the Aquatic Environment (DeTER)', 'National Risk Assessment of Impacts of Climate Change: Bridging the Gap to Adaptation Action', 'Building Coastal and Marine Resilience in Ireland', 'CIViC: Critical Infrastructure Vulnerability to Climate Change', 'Evaluating Ireland’s Climate Policy Performance', 'Methodologies for Financing and Costing of Climate Impacts and Future Adaptation Actions: Transport Networks in Ireland', 'Ireland’s Atmospheric Composition and Climate Change Network', 'Synthesis of Literature and Preliminary Modelling Relevant to Society-wide Scenarios for Effective Climate Change Mitigation in Ireland'], 'research_number': ['Research 259', 'Research 346', 'Research 429', 'Research 369', 'Research 362', 'Research 360', 'Research 357', 'Research 352'], 'year': ['2018', '2020', '2023', '2021', '2021', '2021', '2020', '2020'], 'ISBN': ['978-1-84095-796-9', '978-1-84095-948-2', '978-1-80009-091-0', '978-1-84095-986-4', '978-1-84095-969-7', '978-1-84095-967-3', '978-1-84095-962-8', '978-1-84095-956-7'], 'filesize': ['2,041 KB', '5,131 KB', '5,085 KB', '4,036 KB', '1,432 KB', '4,075 KB', '8,278 KB', '4,106 KB'], 'format': ['pdf', 'pdf', 'pdf', 'pdf', 'pdf', 'pdf', 'pdf', 'pdf'], 'link': ['https://www.epa.ie/publications/research/environment--health/Research_Report_259.pdf', 'https://www.epa.ie/publications/research/climate-change/Research_Report_346.pdf', 'https://www.epa.ie/publications/research/climate-change/Research_Report_429.pdf', 'https://www.epa.ie/publications/research/climate-change/Research_Report_369.pdf', 'https://www.epa.ie/publications/research/climate-change/Research_Report_362.pdf', 'https://www.epa.ie/publications/research/climate-change/Research_Report_360.pdf', 'https://www.epa.ie/publications/research/climate-change/Research_Report_357.pdf', 'https://www.epa.ie/publications/research/climate-change/Research_Report_352.pdf']}

# %%
'''
transforme dictionary to dataframe
pub_df is dataframe of publications
'''
pub_df= pd.DataFrame(mydict)

# %%
pub_df
# Out:
#                                                title research_number  year  \
# 0  Detection, Toxicology, Environmental Fate and ...    Research 259  2018
# 1  National Risk Assessment of Impacts of Climate...    Research 346  2020
# 2  Building Coastal and Marine Resilience in Ireland    Research 429  2023
# 3  CIViC: Critical Infrastructure Vulnerability t...    Research 369  2021
# 4    Evaluating Ireland’s Climate Policy Performance    Research 362  2021
# 5  Methodologies for Financing and Costing of Cli...    Research 360  2021
# 6  Ireland’s Atmospheric Composition and Climate ...    Research 357  2020
# 7  Synthesis of Literature and Preliminary Modell...    Research 352  2020
#
#                 ISBN  filesize format  \
# 0  978-1-84095-796-9  2,041 KB    pdf
# 1  978-1-84095-948-2  5,131 KB    pdf
# 2  978-1-80009-091-0  5,085 KB    pdf
# 3  978-1-84095-986-4  4,036 KB    pdf
# 4  978-1-84095-969-7  1,432 KB    pdf
# 5  978-1-84095-967-3  4,075 KB    pdf
# 6  978-1-84095-962-8  8,278 KB    pdf
# 7  978-1-84095-956-7  4,106 KB    pdf
#
#                                                 link
# 0  https://www.epa.ie/publications/research/envir...
# 1  https://www.epa.ie/publications/research/clima...
# 2  https://www.epa.ie/publications/research/clima...
# 3  https://www.epa.ie/publications/research/clima...
# 4  https://www.epa.ie/publications/research/clima...
# 5  https://www.epa.ie/publications/research/clima...
# 6  https://www.epa.ie/publications/research/clima...
# 7  https://www.epa.ie/publications/research/clima...

# %%
# saving the dataframe
pub_df.to_csv('webscraper-publications.csv')

# %% [markdown]
# # Part 2. Extract references from PDF

# %% [markdown]
# There are plenty of packages that extract plain text or references from pdf file.
# Unfortunately,  refextractor didn`t work well with the reference formating style that mostly all epa researches have.
# pdfextract, pdftotext, pdfx, PDF2text all works but not great for this task.
# So I chose tika package that extracts content of pdf as plain text.

# %%
# !pip install tika
from tika import parser
# Out:
# Requirement already satisfied: tika in /usr/local/lib/python3.10/dist-packages (2.6.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tika) (67.7.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from tika) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->tika) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->tika) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->tika) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->tika) (2023.7.22)

# %%
links = pub_df['link']

# %%
result=[]

# %%
'''main fuction to extract references that unites small functions
  receives @refstr that is content of pdf file and is presented as plain text
'''
def reference_extractor(refstr):

    reflist = find_references(refstr).split('\n\n')
    source_title = find_source_report_name(refstr)
    reflist = delete_n(reflist)
    create_not_ref = create_list_not_references(reflist)
    #delete from newlist all items that are in not_references
    reflist = [item for item in reflist if item not in create_not_ref]


    return reflist, source_title


def find_references(refstr):
  '''
  To scrape references from the file at first we should find them in the text.
  Usually, word 'references appear in text two times (in the List of Content and as Title of references chapter)
  So we are looking for list of references only in the second part of our text
  Important!
  It`s just an assumption that works for mostly all epa publication.
  '''
  new_str =''

  ref_start = refstr.find('References', len(refstr)//2,len(refstr))
  ref_end = refstr.find('Glossary',len(refstr)//2,len(refstr))
  ref_end2 = refstr.find('Acronyms and Annotations',len(refstr)//2,len(refstr))
  ref_end3 = refstr.find('Abbreviations',len(refstr)//2,len(refstr))
  '''
  When index of
  '''

  if ref_end!=-1:
    new_str = refstr[ref_start+ len('References '):ref_end]
  elif ref_end2!=-1:
    new_str = refstr[ref_start+ len('References '):ref_end2]
  elif ref_end3!=-1:
    new_str= refstr[ref_start+ len('References '):ref_end3]


  return new_str

def delete_n(reflist):
  newlist = []
  for i in range(len(reflist)):
    reflist_split=reflist[i].split('\n')
    reflist_join = " ".join(reflist_split)
    newlist.append(reflist_join)
  return newlist

def create_list_not_references(newlist):
  not_references = []
  for i in range(len(newlist)-1):
    if((len(newlist[i])<4) and (len(newlist[i])>0)):
      not_references.append(newlist[i])
      not_references.append(newlist[i+1])
      not_references.append(newlist[i-1])
  return not_references


def find_source_report_name(str_link1):
  str_link1=str_link1.split('\n\n')
  str_link1 = " ".join(str_link1)
  source_name_begin = str_link1.find('Report')
  source_name_end = str_link1.find('Authors')
  source_name= str_link1[source_name_begin:source_name_end]
  return source_name

# %% [markdown]
# Changes:
# Now it works for any amount of links given

# %%
pub_df
# Out:
#                                                title research_number  year  \
# 0  Detection, Toxicology, Environmental Fate and ...    Research 259  2018
# 1  National Risk Assessment of Impacts of Climate...    Research 346  2020
# 2  Building Coastal and Marine Resilience in Ireland    Research 429  2023
# 3  CIViC: Critical Infrastructure Vulnerability t...    Research 369  2021
# 4    Evaluating Ireland’s Climate Policy Performance    Research 362  2021
# 5  Methodologies for Financing and Costing of Cli...    Research 360  2021
# 6  Ireland’s Atmospheric Composition and Climate ...    Research 357  2020
# 7  Synthesis of Literature and Preliminary Modell...    Research 352  2020
#
#                 ISBN  filesize format  \
# 0  978-1-84095-796-9  2,041 KB    pdf
# 1  978-1-84095-948-2  5,131 KB    pdf
# 2  978-1-80009-091-0  5,085 KB    pdf
# 3  978-1-84095-986-4  4,036 KB    pdf
# 4  978-1-84095-969-7  1,432 KB    pdf
# 5  978-1-84095-967-3  4,075 KB    pdf
# 6  978-1-84095-962-8  8,278 KB    pdf
# 7  978-1-84095-956-7  4,106 KB    pdf
#
#                                                 link
# 0  https://www.epa.ie/publications/research/envir...
# 1  https://www.epa.ie/publications/research/clima...
# 2  https://www.epa.ie/publications/research/clima...
# 3  https://www.epa.ie/publications/research/clima...
# 4  https://www.epa.ie/publications/research/clima...
# 5  https://www.epa.ie/publications/research/clima...
# 6  https://www.epa.ie/publications/research/clima...
# 7  https://www.epa.ie/publications/research/clima...

# %% [markdown]
# ## Regular expression

# %%
source_target = []
target_count= []
source_titles = []
for i in range(len(links)):
  ref = reference_extractor(parser.from_file(links[i])['content'])
  #every source are concatened with target and 000 (marker) is added between for easier division later
  [ source_target.append(ref[1]+ '000' + j) for j in ref[0]]
  target_count.append(str(len(ref[0])))
  source_titles.append(ref[1])
  df1 = pd.DataFrame(source_target, columns=['targetdf'])
  #split source from targetdf with help of 000 marker
  df1['Source'] = df1['targetdf'].str.split('000', 1).str[0].str.strip()
  #preparation rows before extracting authors names from references
  df1['authors'] = df1['targetdf'].str.split('000', 1).str[1].str.strip()
  #extract 4 numbers that usually are year, in some cases doesnot work properly
  df1['year'] = df1['authors'].str.extract('(\d\d\d\d)', expand=True)
  #author are placed in one column
  df1['authors'] = df1['authors'].str.split('\s\d{4}\w*.\s*', 1).str[0].str.strip()
  df1['titleandextra'] = df1['targetdf'].str.split('\s\d{4}\w*.\s*', 1).str[1].str.strip()

  df1['Target'] = df1['titleandextra'].str.split('[^\d.\d°C]\.\s?', 1).str[0].str.strip()
  df1['extra'] = df1['titleandextra'].str.split('\?|\.\s?', 1).str[1].str.strip()
# Out:
# 2023-08-21 13:07:36,101 [MainThread  ] [INFO ]  Retrieving https://www.epa.ie/publications/research/environment--health/Research_Report_259.pdf to /tmp/publications-research-environment-health-research_report_259.pdf.
# INFO:tika.tika:Retrieving https://www.epa.ie/publications/research/environment--health/Research_Report_259.pdf to /tmp/publications-research-environment-health-research_report_259.pdf.
# <ipython-input-55-eb6a423c5f05>:12: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df1['Source'] = df1['targetdf'].str.split('000', 1).str[0].str.strip()
# <ipython-input-55-eb6a423c5f05>:14: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df1['authors'] = df1['targetdf'].str.split('000', 1).str[1].str.strip()
# <ipython-input-55-eb6a423c5f05>:18: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df1['authors'] = df1['authors'].str.split('\s\d{4}\w*.\s*', 1).str[0].str.strip()
# <ipython-input-55-eb6a423c5f05>:19: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df1['titleandextra'] = df1['targetdf'].str.split('\s\d{4}\w*.\s*', 1).str[1].str.strip()
# <ipython-input-55-eb6a423c5f05>:21: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df1['Target'] = df1['titleandextra'].str.split('[^\d.\d°C]\.\s?', 1).str[0].str.strip()
# <ipython-input-55-eb6a423c5f05>:22: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df1['extra'] = df1['titleandextra'].str.split('\?|\.\s?', 1).str[1].str.strip()
# 2023-08-21 13:07:38,931 [MainThread  ] [INFO ]  Retrieving https://www.epa.ie/publications/research/climate-change/Research_Report_346.pdf to /tmp/publications-research-climate-change-research_report_346.pdf.
# INFO:tika.tika:Retrieving https://www.epa.ie/publications/research/climate-change/Research_Report_346.pdf to /tmp/publications-research-climate-change-research_report_346.pdf.
# <ipython-input-55-eb6a423c5f05>:12: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df1['Source'] = df1['targetdf'].str.split('000', 1).str[0].str.strip()
# <ipython-input-55-eb6a423c5f05>:14: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df1['authors'] = df1['targetdf'].str.split('000', 1).str[1].str.strip()
# <ipython-input-55-eb6a423c5f05>:18: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df1['authors'] = df1['authors'].str.split('\s\d{4}\w*.\s*', 1).str[0].str.strip()
# <ipython-input-55-eb6a423c5f05>:19: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df1['titleandextra'] = df1['targetdf'].str.split('\s\d{4}\w*.\s*', 1).str[1].str.strip()
# <ipython-input-55-eb6a423c5f05>:21: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df1['Target'] = df1['titleandextra'].str.split('[^\d.\d°C]\.\s?', 1).str[0].str.strip()
# <ipython-input-55-eb6a423c5f05>:22: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df1['extra'] = df1['titleandextra'].str.split('\?|\.\s?', 1).str[1].str.strip()
# 2023-08-21 13:07:42,472 [MainThread  ] [INFO ]  Retrieving https://www.epa.ie/publications/research/climate-change/Research_Report_429.pdf to /tmp/publications-research-climate-change-research_report_429.pdf.
# INFO:tika.tika:Retrieving https://www.epa.ie/publications/research/climate-change/Research_Report_429.pdf to /tmp/publications-research-climate-change-research_report_429.pdf.
# <ipython-input-55-eb6a423c5f05>:12: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df1['Source'] = df1['targetdf'].str.split('000', 1).str[0].str.strip()
# <ipython-input-55-eb6a423c5f05>:14: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df1['authors'] = df1['targetdf'].str.split('000', 1).str[1].str.strip()
# <ipython-input-55-eb6a423c5f05>:18: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df1['authors'] = df1['authors'].str.split('\s\d{4}\w*.\s*', 1).str[0].str.strip()
# <ipython-input-55-eb6a423c5f05>:19: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df1['titleandextra'] = df1['targetdf'].str.split('\s\d{4}\w*.\s*', 1).str[1].str.strip()
# <ipython-input-55-eb6a423c5f05>:21: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df1['Target'] = df1['titleandextra'].str.split('[^\d.\d°C]\.\s?', 1).str[0].str.strip()
# <ipython-input-55-eb6a423c5f05>:22: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df1['extra'] = df1['titleandextra'].str.split('\?|\.\s?', 1).str[1].str.strip()
# 2023-08-21 13:07:45,913 [MainThread  ] [INFO ]  Retrieving https://www.epa.ie/publications/research/climate-change/Research_Report_369.pdf to /tmp/publications-research-climate-change-research_report_369.pdf.
# INFO:tika.tika:Retrieving https://www.epa.ie/publications/research/climate-change/Research_Report_369.pdf to /tmp/publications-research-climate-change-research_report_369.pdf.
# <ipython-input-55-eb6a423c5f05>:12: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df1['Source'] = df1['targetdf'].str.split('000', 1).str[0].str.strip()
# <ipython-input-55-eb6a423c5f05>:14: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df1['authors'] = df1['targetdf'].str.split('000', 1).str[1].str.strip()
# <ipython-input-55-eb6a423c5f05>:18: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df1['authors'] = df1['authors'].str.split('\s\d{4}\w*.\s*', 1).str[0].str.strip()
# <ipython-input-55-eb6a423c5f05>:19: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df1['titleandextra'] = df1['targetdf'].str.split('\s\d{4}\w*.\s*', 1).str[1].str.strip()
# <ipython-input-55-eb6a423c5f05>:21: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df1['Target'] = df1['titleandextra'].str.split('[^\d.\d°C]\.\s?', 1).str[0].str.strip()
# <ipython-input-55-eb6a423c5f05>:22: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df1['extra'] = df1['titleandextra'].str.split('\?|\.\s?', 1).str[1].str.strip()
# 2023-08-21 13:07:50,954 [MainThread  ] [INFO ]  Retrieving https://www.epa.ie/publications/research/climate-change/Research_Report_362.pdf to /tmp/publications-research-climate-change-research_report_362.pdf.
# INFO:tika.tika:Retrieving https://www.epa.ie/publications/research/climate-change/Research_Report_362.pdf to /tmp/publications-research-climate-change-research_report_362.pdf.
# <ipython-input-55-eb6a423c5f05>:12: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df1['Source'] = df1['targetdf'].str.split('000', 1).str[0].str.strip()
# <ipython-input-55-eb6a423c5f05>:14: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df1['authors'] = df1['targetdf'].str.split('000', 1).str[1].str.strip()
# <ipython-input-55-eb6a423c5f05>:18: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df1['authors'] = df1['authors'].str.split('\s\d{4}\w*.\s*', 1).str[0].str.strip()
# <ipython-input-55-eb6a423c5f05>:19: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df1['titleandextra'] = df1['targetdf'].str.split('\s\d{4}\w*.\s*', 1).str[1].str.strip()
# <ipython-input-55-eb6a423c5f05>:21: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df1['Target'] = df1['titleandextra'].str.split('[^\d.\d°C]\.\s?', 1).str[0].str.strip()
# <ipython-input-55-eb6a423c5f05>:22: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df1['extra'] = df1['titleandextra'].str.split('\?|\.\s?', 1).str[1].str.strip()
# 2023-08-21 13:07:52,433 [MainThread  ] [INFO ]  Retrieving https://www.epa.ie/publications/research/climate-change/Research_Report_360.pdf to /tmp/publications-research-climate-change-research_report_360.pdf.
# INFO:tika.tika:Retrieving https://www.epa.ie/publications/research/climate-change/Research_Report_360.pdf to /tmp/publications-research-climate-change-research_report_360.pdf.
# <ipython-input-55-eb6a423c5f05>:12: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df1['Source'] = df1['targetdf'].str.split('000', 1).str[0].str.strip()
# <ipython-input-55-eb6a423c5f05>:14: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df1['authors'] = df1['targetdf'].str.split('000', 1).str[1].str.strip()
# <ipython-input-55-eb6a423c5f05>:18: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df1['authors'] = df1['authors'].str.split('\s\d{4}\w*.\s*', 1).str[0].str.strip()
# <ipython-input-55-eb6a423c5f05>:19: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df1['titleandextra'] = df1['targetdf'].str.split('\s\d{4}\w*.\s*', 1).str[1].str.strip()
# <ipython-input-55-eb6a423c5f05>:21: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df1['Target'] = df1['titleandextra'].str.split('[^\d.\d°C]\.\s?', 1).str[0].str.strip()
# <ipython-input-55-eb6a423c5f05>:22: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df1['extra'] = df1['titleandextra'].str.split('\?|\.\s?', 1).str[1].str.strip()
# 2023-08-21 13:07:54,243 [MainThread  ] [INFO ]  Retrieving https://www.epa.ie/publications/research/climate-change/Research_Report_357.pdf to /tmp/publications-research-climate-change-research_report_357.pdf.
# INFO:tika.tika:Retrieving https://www.epa.ie/publications/research/climate-change/Research_Report_357.pdf to /tmp/publications-research-climate-change-research_report_357.pdf.
# <ipython-input-55-eb6a423c5f05>:12: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df1['Source'] = df1['targetdf'].str.split('000', 1).str[0].str.strip()
# <ipython-input-55-eb6a423c5f05>:14: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df1['authors'] = df1['targetdf'].str.split('000', 1).str[1].str.strip()
# <ipython-input-55-eb6a423c5f05>:18: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df1['authors'] = df1['authors'].str.split('\s\d{4}\w*.\s*', 1).str[0].str.strip()
# <ipython-input-55-eb6a423c5f05>:19: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df1['titleandextra'] = df1['targetdf'].str.split('\s\d{4}\w*.\s*', 1).str[1].str.strip()
# <ipython-input-55-eb6a423c5f05>:21: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df1['Target'] = df1['titleandextra'].str.split('[^\d.\d°C]\.\s?', 1).str[0].str.strip()
# <ipython-input-55-eb6a423c5f05>:22: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df1['extra'] = df1['titleandextra'].str.split('\?|\.\s?', 1).str[1].str.strip()
# 2023-08-21 13:07:56,283 [MainThread  ] [INFO ]  Retrieving https://www.epa.ie/publications/research/climate-change/Research_Report_352.pdf to /tmp/publications-research-climate-change-research_report_352.pdf.
# INFO:tika.tika:Retrieving https://www.epa.ie/publications/research/climate-change/Research_Report_352.pdf to /tmp/publications-research-climate-change-research_report_352.pdf.
# <ipython-input-55-eb6a423c5f05>:12: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df1['Source'] = df1['targetdf'].str.split('000', 1).str[0].str.strip()
# <ipython-input-55-eb6a423c5f05>:14: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df1['authors'] = df1['targetdf'].str.split('000', 1).str[1].str.strip()
# <ipython-input-55-eb6a423c5f05>:18: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df1['authors'] = df1['authors'].str.split('\s\d{4}\w*.\s*', 1).str[0].str.strip()
# <ipython-input-55-eb6a423c5f05>:19: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df1['titleandextra'] = df1['targetdf'].str.split('\s\d{4}\w*.\s*', 1).str[1].str.strip()
# <ipython-input-55-eb6a423c5f05>:21: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df1['Target'] = df1['titleandextra'].str.split('[^\d.\d°C]\.\s?', 1).str[0].str.strip()
# <ipython-input-55-eb6a423c5f05>:22: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df1['extra'] = df1['titleandextra'].str.split('\?|\.\s?', 1).str[1].str.strip()

# %% [markdown]
# I want to know how many references will be wiped out during cleaning.
# To the first dataframe that consists of web scraped information I added num_of_ref.
# num_of_ref - is variabe that holds how many references source publication had.
# Because of nature of Bibliometric analysis, it`s not effective to leave all references, especially those that lead to websites, articles of goverment regulations and law.

# %%
pub_df['num_of_ref'] = target_count
pub_df['isEPA'] = 1
pub_df['source_title_from_ref'] = source_titles #this variable to check if tika module works correcrtly

# %%
pub_df
# Out:
#                                                title research_number  year  \
# 0  Detection, Toxicology, Environmental Fate and ...    Research 259  2018
# 1  National Risk Assessment of Impacts of Climate...    Research 346  2020
# 2  Building Coastal and Marine Resilience in Ireland    Research 429  2023
# 3  CIViC: Critical Infrastructure Vulnerability t...    Research 369  2021
# 4    Evaluating Ireland’s Climate Policy Performance    Research 362  2021
# 5  Methodologies for Financing and Costing of Cli...    Research 360  2021
# 6  Ireland’s Atmospheric Composition and Climate ...    Research 357  2020
# 7  Synthesis of Literature and Preliminary Modell...    Research 352  2020
#
#                 ISBN  filesize format  \
# 0  978-1-84095-796-9  2,041 KB    pdf
# 1  978-1-84095-948-2  5,131 KB    pdf
# 2  978-1-80009-091-0  5,085 KB    pdf
# 3  978-1-84095-986-4  4,036 KB    pdf
# 4  978-1-84095-969-7  1,432 KB    pdf
# 5  978-1-84095-967-3  4,075 KB    pdf
# 6  978-1-84095-962-8  8,278 KB    pdf
# 7  978-1-84095-956-7  4,106 KB    pdf
#
#                                                 link num_of_ref  isEPA  \
# 0  https://www.epa.ie/publications/research/envir...        134      1
# 1  https://www.epa.ie/publications/research/clima...        174      1
# 2  https://www.epa.ie/publications/research/clima...        177      1
# 3  https://www.epa.ie/publications/research/clima...        107      1
# 4  https://www.epa.ie/publications/research/clima...         67      1
# 5  https://www.epa.ie/publications/research/clima...         57      1
# 6  https://www.epa.ie/publications/research/clima...         14      1
# 7  https://www.epa.ie/publications/research/clima...        247      1
#
#                                source_title_from_ref
# 0  Report No. Detection, Toxicology, Environmenta...
# 1  Report No.346 National Risk Assessment of \nIm...
# 2  Report No.  Building Coastal and Marine \nResi...
# 3  Report No.369 CIViC: Critical \nInfrastructure...
# 4  Report No.362 Evaluating Ireland’s Climate \nP...
# 5  Report No.360 Methodologies for Financing and ...
# 6  Report No.357 Ireland’s Atmospheric Compositio...
# 7  Report No.352 Synthesis of Literature and Prel...

# %%
'''
this have no direct connection to other code. I wanted to add small table about sources to the github page

we can create a html table from DataFrame to add to website where graph will be published
'''

pubdf1 = pub_df[['title', 'year', 'num_of_ref', 'research_number', 'link']]
pubdf1.to_html()
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>title</th>\n      <th>year</th>\n      <th>num_of_ref</th>\n      <th>research_number</th>\n      <th>link</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>Detection, Toxicology, Environmental Fate and Risk Assessment of Nanoparticles in the Aquatic Environment (DeTER)</td>\n      <td>2018</td>\n      <td>134</td>\n      <td>Research 259</td>\n      <td>https://www.epa.ie/publications/research/environment--health/Research_Report_259.pdf</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>National Risk Assessment of Impacts of Climate Change: Bridging the Gap to Adaptation Action</td>\n      <td>2020</td>\n      <td>174</td>\n      <td>Research 346</td>\n      <td>https://www.epa.ie/publications/research/climate-change/Research_Report_346.pdf</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>Building Coastal and Marine Resilience in Ireland</td>\n      <td>2023</td>\n      <td>177</td>\n      <td>Research 429</td>\n      <td>https://www.epa.ie/publications/research/climate-change/Research_Report_429.pdf</td>\n    </tr>\n    <tr>\n      <th>3</th>\n      <td>CIViC: Critical Infrastructure Vulnerability to Climate Change</td>\n      <td>2021</td>\n      <td>107</td>\n      <td>Research 369</td>\n      <td>https://www.epa.ie/publications/research/climate-change/Research_Report_369.pdf</td>\n    </tr>\n    <tr>\n      <th>4</th>\n      <td>Evaluating Ireland’s Climate Policy Performance</td>\n      <td>2021</td>\n      <td>67</td>\n      <td>Research 362</td>\n      <td>https://www.epa.ie/publications/research/climate-change/Research_Report_362.pdf</td>\n    </tr>\n    <tr>\n      <th>5</th>\n      <td>Methodologies for Financing and Costing of Climate Impacts and Future Adaptation Actions: Transport Networks in Ireland</td>\n      <td>2021</td>\n      <td>57</td>\n      <td>Research 360</td>\n      <td>https://www.epa.ie/publications/research/climate-change/Research_Report_360.pdf</td>\n    </tr>\n    <tr>\n      <th>6</th>\n      <td>Ireland’s Atmospheric Composition and Climate Change Network</td>\n      <td>2020</td>\n      <td>14</td>\n      <td>Research 357</td>\n      <td>https://www.epa.ie/publications/research/climate-change/Research_Report_357.pdf</td>\n    </tr>\n    <tr>\n      <th>7</th>\n      <td>Synthesis of Literature and Preliminary Modelling Relevant to Society-wide Scenarios for Effective Climate Change Mitigation in Ireland</td>\n      <td>2020</td>\n      <td>247</td>\n      <td>Research 352</td>\n      <td>https://www.epa.ie/publications/research/climate-change/Research_Report_352.pdf</td>\n    </tr>\n  </tbody>\n</table>'

# %%
df1
# Out:
#                                               targetdf  \
# 0    Report No. Detection, Toxicology, Environmenta...
# 1    Report No. Detection, Toxicology, Environmenta...
# 2    Report No. Detection, Toxicology, Environmenta...
# 3    Report No. Detection, Toxicology, Environmenta...
# 4    Report No. Detection, Toxicology, Environmenta...
# ..                                                 ...
# 972  Report No.352 Synthesis of Literature and Prel...
# 973  Report No.352 Synthesis of Literature and Prel...
# 974  Report No.352 Synthesis of Literature and Prel...
# 975  Report No.352 Synthesis of Literature and Prel...
# 976  Report No.352 Synthesis of Literature and Prel...
#
#                                                 Source  \
# 0    Report No. Detection, Toxicology, Environmenta...
# 1    Report No. Detection, Toxicology, Environmenta...
# 2    Report No. Detection, Toxicology, Environmenta...
# 3    Report No. Detection, Toxicology, Environmenta...
# 4    Report No. Detection, Toxicology, Environmenta...
# ..                                                 ...
# 972  Report No.352 Synthesis of Literature and Prel...
# 973  Report No.352 Synthesis of Literature and Prel...
# 974  Report No.352 Synthesis of Literature and Prel...
# 975  Report No.352 Synthesis of Literature and Prel...
# 976  Report No.352 Synthesis of Literature and Prel...
#
#                                                authors  year  \
# 0    Abou El-Nour, K.M.M.M., Eftaiha, A.A., Al-Wart...  2010
# 1    Akaighe, N., Maccuspie, R.I., Navarro, D.A., A...  2011
# 2                                     Alexander, J.W.,  2009
# 3    Amato, E., Diaz-Fernandez, Y.A., Taglietti, A....  2011
# 4                                      Anderson, R.A.,  2005
# ..                                                 ...   ...
# 972                                        World Bank,  2019
# 973                                        Zoloth, L.,  2017
# 974  Zscheischler, J., Westra, S., van den Hurk, B....  2018
# 975  AD Anaerobic digestion BAU Business as usual C...  2019
# 976  SR1.5 IPCC Special report on global warming of...  1000
#
#                                          titleandextra  \
# 0    Synthesis and applications of  silver nanopart...
# 1    Humic  acid-induced silver nanoparticle format...
# 2    History of the medical use of  silver. Surgica...
# 3    Synthesis, characterization and antibacterial ...
# 4    Algal Culturing Techniques.  Elsevier Academic...
# ..                                                 ...
# 972  World GDP data. Available online:  http://api....
# 973  At the last well on Earth: climate change  is ...
# 974  Future climate risk from compound events.  Nat...
# 975  Climate Action Plan CBA Cost–benefit analysis ...
# 976                                                NaN
#
#                                                 Target  \
# 0    Synthesis and applications of  silver nanopart...
# 1    Humic  acid-induced silver nanoparticle format...
# 2                 History of the medical use of  silve
# 3    Synthesis, characterization and antibacterial ...
# 4                            Algal Culturing Technique
# ..                                                 ...
# 972                                      World GDP dat
# 973  At the last well on Earth: climate change  is ...
# 974            Future climate risk from compound event
# 975  Climate Action Plan CBA Cost–benefit analysis ...
# 976                                                NaN
#
#                                                  extra
# 0            Arabian Journal of Chemistry 3:  135–140.
# 1    Environmental  Science & Technology 45: 3895–3...
# 2                     Surgical infections 10: 289–292.
# 3                              Langmuir 27: 9165–9173.
# 4    Elsevier Academic Press/Phycological Society o...
# ..                                                 ...
# 972  Available online:  http://api.worldbank.org/v2...
# 973  Journal of Feminist Studies  in Religion 33: 1...
# 974  Nature Climate Change 8: 469–477. https://doi....
# 975                                                NaN
# 976                                                NaN
#
# [977 rows x 7 columns]

# %%
'''
is_EPA - boolean that True if Target are EPA funded, False if not (or maybe we don`t have this informatin in the reference )

Is true if Environmental Protection
                EPA
                Johnstown Castle
will be found in the last part of references after authors.
'''
reg_exp = r'(Environmental\sProtection)|(EPA)|(Johnstown\sCastle)'
df1['isEPA'] = np.where(df1['extra'].str.match(reg_exp)!=True, 0, 1)

# %%
df1[df1['isEPA']==1]
# Out:
#                                               targetdf  \
# 18   Report No. Detection, Toxicology, Environmenta...
# 33   Report No. Detection, Toxicology, Environmenta...
# 34   Report No. Detection, Toxicology, Environmenta...
# 142  Report No.346 National Risk Assessment of \nIm...
# 152  Report No.346 National Risk Assessment of \nIm...
# 153  Report No.346 National Risk Assessment of \nIm...
# 177  Report No.346 National Risk Assessment of \nIm...
# 182  Report No.346 National Risk Assessment of \nIm...
# 187  Report No.346 National Risk Assessment of \nIm...
# 217  Report No.346 National Risk Assessment of \nIm...
# 220  Report No.346 National Risk Assessment of \nIm...
# 258  Report No.346 National Risk Assessment of \nIm...
# 273  Report No.346 National Risk Assessment of \nIm...
# 275  Report No.346 National Risk Assessment of \nIm...
# 279  Report No.346 National Risk Assessment of \nIm...
# 281  Report No.346 National Risk Assessment of \nIm...
# 293  Report No.346 National Risk Assessment of \nIm...
# 340  Report No.  Building Coastal and Marine \nResi...
# 343  Report No.  Building Coastal and Marine \nResi...
# 375  Report No.  Building Coastal and Marine \nResi...
# 386  Report No.  Building Coastal and Marine \nResi...
# 446  Report No.  Building Coastal and Marine \nResi...
# 482  Report No.  Building Coastal and Marine \nResi...
# 506  Report No.369 CIViC: Critical \nInfrastructure...
# 516  Report No.369 CIViC: Critical \nInfrastructure...
# 552  Report No.369 CIViC: Critical \nInfrastructure...
# 593  Report No.362 Evaluating Ireland’s Climate \nP...
# 618  Report No.362 Evaluating Ireland’s Climate \nP...
# 627  Report No.362 Evaluating Ireland’s Climate \nP...
# 649  Report No.362 Evaluating Ireland’s Climate \nP...
# 650  Report No.362 Evaluating Ireland’s Climate \nP...
# 665  Report No.360 Methodologies for Financing and ...
# 666  Report No.360 Methodologies for Financing and ...
# 678  Report No.360 Methodologies for Financing and ...
# 700  Report No.360 Methodologies for Financing and ...
# 724  Report No.357 Ireland’s Atmospheric Compositio...
# 794  Report No.352 Synthesis of Literature and Prel...
# 795  Report No.352 Synthesis of Literature and Prel...
# 800  Report No.352 Synthesis of Literature and Prel...
# 888  Report No.352 Synthesis of Literature and Prel...
# 890  Report No.352 Synthesis of Literature and Prel...
# 952  Report No.352 Synthesis of Literature and Prel...
#
#                                                 Source  \
# 18   Report No. Detection, Toxicology, Environmenta...
# 33   Report No. Detection, Toxicology, Environmenta...
# 34   Report No. Detection, Toxicology, Environmenta...
# 142  Report No.346 National Risk Assessment of \nIm...
# 152  Report No.346 National Risk Assessment of \nIm...
# 153  Report No.346 National Risk Assessment of \nIm...
# 177  Report No.346 National Risk Assessment of \nIm...
# 182  Report No.346 National Risk Assessment of \nIm...
# 187  Report No.346 National Risk Assessment of \nIm...
# 217  Report No.346 National Risk Assessment of \nIm...
# 220  Report No.346 National Risk Assessment of \nIm...
# 258  Report No.346 National Risk Assessment of \nIm...
# 273  Report No.346 National Risk Assessment of \nIm...
# 275  Report No.346 National Risk Assessment of \nIm...
# 279  Report No.346 National Risk Assessment of \nIm...
# 281  Report No.346 National Risk Assessment of \nIm...
# 293  Report No.346 National Risk Assessment of \nIm...
# 340  Report No.  Building Coastal and Marine \nResi...
# 343  Report No.  Building Coastal and Marine \nResi...
# 375  Report No.  Building Coastal and Marine \nResi...
# 386  Report No.  Building Coastal and Marine \nResi...
# 446  Report No.  Building Coastal and Marine \nResi...
# 482  Report No.  Building Coastal and Marine \nResi...
# 506  Report No.369 CIViC: Critical \nInfrastructure...
# 516  Report No.369 CIViC: Critical \nInfrastructure...
# 552  Report No.369 CIViC: Critical \nInfrastructure...
# 593  Report No.362 Evaluating Ireland’s Climate \nP...
# 618  Report No.362 Evaluating Ireland’s Climate \nP...
# 627  Report No.362 Evaluating Ireland’s Climate \nP...
# 649  Report No.362 Evaluating Ireland’s Climate \nP...
# 650  Report No.362 Evaluating Ireland’s Climate \nP...
# 665  Report No.360 Methodologies for Financing and ...
# 666  Report No.360 Methodologies for Financing and ...
# 678  Report No.360 Methodologies for Financing and ...
# 700  Report No.360 Methodologies for Financing and ...
# 724  Report No.357 Ireland’s Atmospheric Compositio...
# 794  Report No.352 Synthesis of Literature and Prel...
# 795  Report No.352 Synthesis of Literature and Prel...
# 800  Report No.352 Synthesis of Literature and Prel...
# 888  Report No.352 Synthesis of Literature and Prel...
# 890  Report No.352 Synthesis of Literature and Prel...
# 952  Report No.352 Synthesis of Literature and Prel...
#
#                                                authors  year  \
# 18                       Cunningham, S. and Joshi, L.,  2015
# 33              EPA (Environmental Protection Agency),  2002
# 34              EPA (Environmental Protection Agency),  2011
# 142  Bullock, C., Fealy, R., Clinch, J.P. and O’She...  2015
# 152                          Coll, J. and Sweeney, J.,  2013
# 153  Coll, J., Bourke, D., Gormally, M., Sheehy Ske...  2012
# 177         Desmond, M., O’Brien, P. and McGovern, F.,  2017
# 182                      Donnelly, A. and O’Neill, B.,  2013
# 187                                         Dwyer, N.,  2012
# 217              Hall, J., Murphy, C. and Sweeney, J.,  2012
# 220  Hawchar, L., Naughton, O., Stewart, M.G. and R...  2020
# 258                           Lydon, K. and Smith, G.,  2014
# 273                                         Nolan, P.,  2015
# 275                         O’Dwyer, B. and Gault, J.,  2017
# 279  Paranunzio, R., O’Dwyer, B., Alexander, P.J., ...  2020
# 281  Pascal, M., Goodman, P., Clancy, L. and Schwar...  2013
# 293  Sweeney, J., Albanito, F., Brereton, A., Caffa...  2008
# 340                            Dekker, S., Torney, D.,  2021
# 343            Desmond, M., O’Brien, P., McGovern, F.,  2017
# 375                   Flood, S., Dwyer, N., Gault, J.,  2021
# 386                                          Gray, S.,  2015
# 446           O’Reilly, G., O’Brien, P., McGovern, F.,  2013
# 482                Wall, B., Cahalane, A., Derham, J.,  2020
# 506         Desmond, M., O’Brien, P. and McGovern, F.,  2009
# 516             EPA (Environmental Protection Agency),  2016
# 552                                         Nolan, P.,  2015
# 593  Bullock, C., Rowan, F., Clinch, J.P. and O’She...  2015
# 618                                         Dwyer, N.,  2012
# 627             EPA (Environmental Protection Agency),  2019
# 649  Ó Gallachóir, B.P., Chiodi, A., Gargiulo, M., ...  2012
# 650        O’Reilly, G., O’Brien, P. and McGovern, F.,  2012
# 665        Browne, D., Caulfield, B. and O’Mahony, M.,  2011
# 666  Bullock, C., Fealy, R., Clinch, J.P. and O’She...  2015
# 678              Fealy, R., Bruyére, C. and Duffy, C.,  2018
# 700                                         Nolan, P.,  2015
# 724        Leinert, S., McGovern, F. and Jennings, G.,  2008
# 794  Duffy, P., Black, K., Hyde, B., Ryan, A.M. and...  2019
# 795                                         Dwyer, N.,  2012
# 800      Ellis, G., Hume, T., Barry, J. and Curry, R.,  2019
# 888                        McMullin, B. and Price, P.,  2020
# 890  McMullin, B., Jones, M.B., Price, P. and Rice,...  2020
# 952    Sweeney, J., Albanito, F., Brereton, A. et al.,  2008
#
#                                          titleandextra  \
# 18   Assessment of  Exposure of Marine and Freshwat...
# 33   Water  Treatment Manuals: Coagulation, Floccul...
# 34   Water  Framework Status Update Based on Monito...
# 142  ADAPT: Quantifying the Costs and Benefits  Ass...
# 152  Current and Future  Vulnerabilities to Climate...
# 153  Winners and Losers:  Climate Change Impacts on...
# 177  A Summary of the State of Knowledge on Climate...
# 182  Climate Change  Impacts on Phenology: Implicat...
# 187  The Status of Ireland’s Climate,  2012. Enviro...
# 217  Robust  Adaptation to Climate Change in the Wa...
# 220  Critical Infrastructure Vulnerability to Clima...
# 258  CORINE Landcover 2012  Ireland Final Report. E...
# 273  Ensemble of Regional Climate Model  Projection...
# 275  The Development of  an Irish Climate Informati...
# 279  Large Urban Area  Adaptation (Urb-ADAPT). Envi...
# 281  Extreme Temperatures and Mortality in Ireland....
# 293  Climate Change – Refining the Impacts for Irel...
# 340  Evaluating Ireland’s Climate  Policy Performan...
# 343  A  Summary of the State of Knowledge on Climat...
# 375  Policy Coherence  in Adaptation Studies: Selec...
# 386  Local Authority Adaptation Strategy  Developme...
# 446  Addressing  Climate Change Challenges in Irela...
# 482  Ireland’s  Environment – An Integrated Assessm...
# 506  A Summary of the State of Knowledge on Climate...
# 516  Urban  Waste Water Treatment in 2016. EPA, Joh...
# 552  Ensemble of Regional Climate Model  Projection...
# 593  ADAPT: Quantifying the Costs and Benefits  Ass...
# 618  The Status of Ireland’s Climate.  Environmenta...
# 627  Ireland’s  Provisional Greenhouse Gas Emission...
# 649  Irish TIMES Energy  Systems Model. Environment...
# 650  Addressing Climate Change Challenges in Irelan...
# 665  EPA  Climate Change Research Programme 2007–20...
# 666  ADAPT: Quantifying the Costs and Benefits  Ass...
# 678  Regional  Climate Model Simulations for Irelan...
# 700  Ensemble of Regional Climate Model  Projection...
# 724  New  Transboundary Air Pollution Monitoring Ca...
# 794  Ireland National Inventory Report  2019 – Gree...
# 795  The Status of Ireland’s Climate, 2012.  Enviro...
# 800  Catalysing and Characterising Transition.  Env...
# 888  Society-wide Scenarios  for Effective Climate ...
# 890  IE-NETs: Investigating the Potential for  Nega...
# 952  Climate Change – Refining the Impacts for Irel...
#
#                                                 Target  \
# 18   Assessment of  Exposure of Marine and Freshwat...
# 33   Water  Treatment Manuals: Coagulation, Floccul...
# 34   Water  Framework Status Update Based on Monito...
# 142  ADAPT: Quantifying the Costs and Benefits  Ass...
# 152  Current and Future  Vulnerabilities to Climate...
# 153  Winners and Losers:  Climate Change Impacts on...
# 177  A Summary of the State of Knowledge on Climate...
# 182  Climate Change  Impacts on Phenology: Implicat...
# 187  The Status of Ireland’s Climate,  2012. Enviro...
# 217  Robust  Adaptation to Climate Change in the Wa...
# 220  Critical Infrastructure Vulnerability to Clima...
# 258         CORINE Landcover 2012  Ireland Final Repor
# 273  Ensemble of Regional Climate Model  Projection...
# 275  The Development of  an Irish Climate Informati...
# 279            Large Urban Area  Adaptation (Urb-ADAPT
# 281       Extreme Temperatures and Mortality in Irelan
# 293   Climate Change – Refining the Impacts for Irelan
# 340    Evaluating Ireland’s Climate  Policy Performanc
# 343  A  Summary of the State of Knowledge on Climat...
# 375  Policy Coherence  in Adaptation Studies: Selec...
# 386  Local Authority Adaptation Strategy  Developme...
# 446    Addressing  Climate Change Challenges in Irelan
# 482  Ireland’s  Environment – An Integrated Assessm...
# 506  A Summary of the State of Knowledge on Climate...
# 516  Urban  Waste Water Treatment in 2016. EPA, Joh...
# 552  Ensemble of Regional Climate Model  Projection...
# 593  ADAPT: Quantifying the Costs and Benefits  Ass...
# 618                     The Status of Ireland’s Climat
# 627  Ireland’s  Provisional Greenhouse Gas Emission...
# 649                   Irish TIMES Energy  Systems Mode
# 650     Addressing Climate Change Challenges in Irelan
# 665  EPA  Climate Change Research Programme 2007–20...
# 666  ADAPT: Quantifying the Costs and Benefits  Ass...
# 678  Regional  Climate Model Simulations for Irelan...
# 700  Ensemble of Regional Climate Model  Projection...
# 724  New  Transboundary Air Pollution Monitoring Ca...
# 794  Ireland National Inventory Report  2019 – Gree...
# 795  The Status of Ireland’s Climate, 2012.  Enviro...
# 800            Catalysing and Characterising Transitio
# 888  Society-wide Scenarios  for Effective Climate ...
# 890  IE-NETs: Investigating the Potential for  Nega...
# 952   Climate Change – Refining the Impacts for Irelan
#
#                                                  extra  isEPA
# 18   Environmental Protection  Agency, Johnstown Ca...      1
# 33                     EPA, Johnstown Castle, Ireland.      1
# 34                     EPA, Johnstown Castle, Ireland.      1
# 142  Environmental Protection Agency, Johnstown Cas...      1
# 152  Environmental Protection Agency, Johnstown Cas...      1
# 153  Environmental Protection Agency, Johnstown Cas...      1
# 177  Environmental Protection  Agency, Johnstown Ca...      1
# 182  Environmental Protection Agency,  Johnstown Ca...      1
# 187  Environmental Protection Agency, Johnstown  Ca...      1
# 217  Environmental Protection Agency, Johnstown  Ca...      1
# 220  Environmental Protection Agency,  Johnstown Ca...      1
# 258  Environmental Protection Agency,  Johnstown Ca...      1
# 273  Environmental Protection  Agency, Johnstown Ca...      1
# 275  Environmental Protection Agency,  Johnstown Ca...      1
# 279  Environmental Protection  Agency, Johnstown Ca...      1
# 281  Environmental Protection Agency, Johnstown Cas...      1
# 293  Environmental Protection Agency, Johnstown Cas...      1
# 340  EPA Report 362. Available  online: https://www...      1
# 343  Environmental Protection  Agency, Johnstown Ca...      1
# 375  Environmental Protection  Agency, Johnstown Ca...      1
# 386  Environmental Protection  Agency, Johnstown Ca...      1
# 446  EPA  Climate Change Research Programme 2007-20...      1
# 482  Environmental Protection Agency, Johnstown Cas...      1
# 506  Environmental Protection  Agency, Johnstown Ca...      1
# 516                   EPA, Johnstown  Castle, Ireland.      1
# 552  Environmental Protection  Agency, Johnstown Ca...      1
# 593  Environmental Protection Agency, Johnstown Cas...      1
# 618  Environmental Protection Agency, Johnstown Cas...      1
# 627                    EPA, Johnstown Castle, Ireland.      1
# 649  Environmental Protection Agency,  Johnstown Ca...      1
# 650  Environmental Protection Agency, Johnstown Cas...      1
# 665  Environmental Protection Agency, Johnstown Cas...      1
# 666  Environmental Protection Agency, Johnstown Cas...      1
# 678  Environmental Protection Agency, Johnstown  Ca...      1
# 700  Environmental Protection  Agency, Johnstown Ca...      1
# 724  Environmental Protection Agency, Johnstown  Ca...      1
# 794  Environmental Protection Agency, Johnstown Cas...      1
# 795  Environmental Protection Agency, Johnstown Cas...      1
# 800  Environmental Protection Agency, Johnstown  Ca...      1
# 888  Environmental Protection Agency,  Johnstown Ca...      1
# 890  Environmental Protection Agency, Johnstown Cas...      1
# 952  Environmental Protection Agency, Johnstown Cas...      1

# %%
df1 = df1[['Source', 'Target', 'isEPA', 'authors', 'extra', 'targetdf','year' ]]
df1
# Out:
#                                                 Source  \
# 0    Report No. Detection, Toxicology, Environmenta...
# 1    Report No. Detection, Toxicology, Environmenta...
# 2    Report No. Detection, Toxicology, Environmenta...
# 3    Report No. Detection, Toxicology, Environmenta...
# 4    Report No. Detection, Toxicology, Environmenta...
# ..                                                 ...
# 972  Report No.352 Synthesis of Literature and Prel...
# 973  Report No.352 Synthesis of Literature and Prel...
# 974  Report No.352 Synthesis of Literature and Prel...
# 975  Report No.352 Synthesis of Literature and Prel...
# 976  Report No.352 Synthesis of Literature and Prel...
#
#                                                 Target  isEPA  \
# 0    Synthesis and applications of  silver nanopart...      0
# 1    Humic  acid-induced silver nanoparticle format...      0
# 2                 History of the medical use of  silve      0
# 3    Synthesis, characterization and antibacterial ...      0
# 4                            Algal Culturing Technique      0
# ..                                                 ...    ...
# 972                                      World GDP dat      0
# 973  At the last well on Earth: climate change  is ...      0
# 974            Future climate risk from compound event      0
# 975  Climate Action Plan CBA Cost–benefit analysis ...      0
# 976                                                NaN      0
#
#                                                authors  \
# 0    Abou El-Nour, K.M.M.M., Eftaiha, A.A., Al-Wart...
# 1    Akaighe, N., Maccuspie, R.I., Navarro, D.A., A...
# 2                                     Alexander, J.W.,
# 3    Amato, E., Diaz-Fernandez, Y.A., Taglietti, A....
# 4                                      Anderson, R.A.,
# ..                                                 ...
# 972                                        World Bank,
# 973                                        Zoloth, L.,
# 974  Zscheischler, J., Westra, S., van den Hurk, B....
# 975  AD Anaerobic digestion BAU Business as usual C...
# 976  SR1.5 IPCC Special report on global warming of...
#
#                                                  extra  \
# 0            Arabian Journal of Chemistry 3:  135–140.
# 1    Environmental  Science & Technology 45: 3895–3...
# 2                     Surgical infections 10: 289–292.
# 3                              Langmuir 27: 9165–9173.
# 4    Elsevier Academic Press/Phycological Society o...
# ..                                                 ...
# 972  Available online:  http://api.worldbank.org/v2...
# 973  Journal of Feminist Studies  in Religion 33: 1...
# 974  Nature Climate Change 8: 469–477. https://doi....
# 975                                                NaN
# 976                                                NaN
#
#                                               targetdf  year
# 0    Report No. Detection, Toxicology, Environmenta...  2010
# 1    Report No. Detection, Toxicology, Environmenta...  2011
# 2    Report No. Detection, Toxicology, Environmenta...  2009
# 3    Report No. Detection, Toxicology, Environmenta...  2011
# 4    Report No. Detection, Toxicology, Environmenta...  2005
# ..                                                 ...   ...
# 972  Report No.352 Synthesis of Literature and Prel...  2019
# 973  Report No.352 Synthesis of Literature and Prel...  2017
# 974  Report No.352 Synthesis of Literature and Prel...  2018
# 975  Report No.352 Synthesis of Literature and Prel...  2019
# 976  Report No.352 Synthesis of Literature and Prel...  1000
#
# [977 rows x 7 columns]

# %%
#There is 42 epa funded publications

df1[df1['isEPA']==1]['Source'].count()
# Out:
# 42

# %%
df1.groupby([df1['isEPA'], 'Source'])['Target'].count()[1][0:]
# Out:
# Source
# Report No.  Building Coastal and Marine \nResilience in Ireland                                                                                            6
# Report No. Detection, Toxicology, Environmental Fate \nand Risk Assessment of Nanoparticles in the  Aquatic Environment (DeTER)                            3
# Report No.346 National Risk Assessment of \nImpacts of Climate Change: Bridging  the Gap to Adaptation Action                                             14
# Report No.352 Synthesis of Literature and Preliminary Modelling\nRelevant to Society-wide Scenarios for Effective Climate Change Mitigation in Ireland     6
# Report No.357 Ireland’s Atmospheric Composition \nand Climate Change Network                                                                               1
# Report No.360 Methodologies for Financing and Costing \nof Climate Impacts and Future Adaptation  Actions: Transport Networks in Ireland                   4
# Report No.362 Evaluating Ireland’s Climate \nPolicy Performance                                                                                            5
# Report No.369 CIViC: Critical \nInfrastructure Vulnerability  to Climate Change                                                                            3
# Name: Target, dtype: int64

# %% [markdown]
# Important note!
# Sometimes Gephi ignore headers from csv files, so it's better to open csv in Excel, then save again as scv utf-8 (maybe try freeze header if still not visible in Gephi).
# Sometimes Excel doesn't read some spanish names or unusual signs, so adding utf-8-sig may be helpful.

# %%
df1.to_csv('citation_test_dataset_one_cycle.csv',encoding='utf-8-sig', header=df1.columns)

# %%
'''

List of warning sent bu gephi:


Issue{message=Node id='Report No.  Building Coastal and Marine , level=WARNING}	WARNING
Issue{message=Node id='Report No. Detection, Toxicology, Environmental Fate , level=WARNING}	WARNING
Issue{message=Node id='Report No.346 National Risk Assessment of , level=WARNING}	WARNING
Issue{message=Node id='Report No.352 Synthesis of Literature and Preliminary Modelling, level=WARNING}	WARNING
Issue{message=Node id='Report No.357 Ireland’s Atmospheric Composition , level=WARNING}	WARNING
Issue{message=Node id='Report No.360 Methodologies for Financing and Costing , level=WARNING}	WARNING
Issue{message=Node id='Report No.362 Evaluating Ireland’s Climate , level=WARNING}	WARNING
Issue{message=Node id='Report No.369 CIViC: Critical , level=WARNING}	WARNING
Issue{message=Parallel edges detected, remember to choose a merge strategy, level=INFO}	INFO
Issue{message=[Record #550] Ignoring edge due to empty source and/or target node ids, level=SEVERE}	SEVERE
Issue{message=[Record #659] Ignoring edge due to empty source and/or target node ids, level=SEVERE}	SEVERE
Issue{message=[Record #721] Ignoring edge due to empty source and/or target node ids, level=SEVERE}	SEVERE
Issue{message=[Record #977] Ignoring edge due to empty source and/or target node ids, level=SEVERE}	SEVERE

'''
# Out:
# "\n\nList of warning sent bu gephi:\n\n\nIssue{message=Node id='Report No.  Building Coastal and Marine , level=WARNING}\tWARNING\nIssue{message=Node id='Report No. Detection, Toxicology, Environmental Fate , level=WARNING}\tWARNING\nIssue{message=Node id='Report No.346 National Risk Assessment of , level=WARNING}\tWARNING\nIssue{message=Node id='Report No.352 Synthesis of Literature and Preliminary Modelling, level=WARNING}\tWARNING\nIssue{message=Node id='Report No.357 Ireland’s Atmospheric Composition , level=WARNING}\tWARNING\nIssue{message=Node id='Report No.360 Methodologies for Financing and Costing , level=WARNING}\tWARNING\nIssue{message=Node id='Report No.362 Evaluating Ireland’s Climate , level=WARNING}\tWARNING\nIssue{message=Node id='Report No.369 CIViC: Critical , level=WARNING}\tWARNING\nIssue{message=Parallel edges detected, remember to choose a merge strategy, level=INFO}\tINFO\nIssue{message=[Record #550] Ignoring edge due to empty source and/or target node ids, level=SEVERE}\tSEVERE\nIssue{message=[Record #659] Ignoring edge due to empty source and/or target node ids, level=SEVERE}\tSEVERE\nIssue{message=[Record #721] Ignoring edge due to empty source and/or target node ids, level=SEVERE}\tSEVERE\nIssue{message=[Record #977] Ignoring edge due to empty source and/or target node ids, level=SEVERE}\tSEVERE\n\n"

# %% [markdown]
# Air
# Biodiversity
# Circular economy
# Climate Change
# Environment & Health
# Environmental Technologies
# Land use, soils and transport
# Socio-economics
# Waste
# Water

# %% [markdown]
# ## Step3: Build a test network of the citation
#  2) An authors network, that shows what authors are cited the most
#  Unfortunately, I can't solve it now. Some papers have 7+ authors and it`s hard to find nice way to built graph from them to whom? From a

# %%
df1
# Out:
#                                                 Source  \
# 0    Report No. Detection, Toxicology, Environmenta...
# 1    Report No. Detection, Toxicology, Environmenta...
# 2    Report No. Detection, Toxicology, Environmenta...
# 3    Report No. Detection, Toxicology, Environmenta...
# 4    Report No. Detection, Toxicology, Environmenta...
# ..                                                 ...
# 972  Report No.352 Synthesis of Literature and Prel...
# 973  Report No.352 Synthesis of Literature and Prel...
# 974  Report No.352 Synthesis of Literature and Prel...
# 975  Report No.352 Synthesis of Literature and Prel...
# 976  Report No.352 Synthesis of Literature and Prel...
#
#                                                 Target  isEPA  \
# 0    Synthesis and applications of  silver nanopart...      0
# 1    Humic  acid-induced silver nanoparticle format...      0
# 2                 History of the medical use of  silve      0
# 3    Synthesis, characterization and antibacterial ...      0
# 4                            Algal Culturing Technique      0
# ..                                                 ...    ...
# 972                                      World GDP dat      0
# 973  At the last well on Earth: climate change  is ...      0
# 974            Future climate risk from compound event      0
# 975  Climate Action Plan CBA Cost–benefit analysis ...      0
# 976                                                NaN      0
#
#                                                authors  \
# 0    Abou El-Nour, K.M.M.M., Eftaiha, A.A., Al-Wart...
# 1    Akaighe, N., Maccuspie, R.I., Navarro, D.A., A...
# 2                                     Alexander, J.W.,
# 3    Amato, E., Diaz-Fernandez, Y.A., Taglietti, A....
# 4                                      Anderson, R.A.,
# ..                                                 ...
# 972                                        World Bank,
# 973                                        Zoloth, L.,
# 974  Zscheischler, J., Westra, S., van den Hurk, B....
# 975  AD Anaerobic digestion BAU Business as usual C...
# 976  SR1.5 IPCC Special report on global warming of...
#
#                                                  extra  \
# 0            Arabian Journal of Chemistry 3:  135–140.
# 1    Environmental  Science & Technology 45: 3895–3...
# 2                     Surgical infections 10: 289–292.
# 3                              Langmuir 27: 9165–9173.
# 4    Elsevier Academic Press/Phycological Society o...
# ..                                                 ...
# 972  Available online:  http://api.worldbank.org/v2...
# 973  Journal of Feminist Studies  in Religion 33: 1...
# 974  Nature Climate Change 8: 469–477. https://doi....
# 975                                                NaN
# 976                                                NaN
#
#                                               targetdf  year
# 0    Report No. Detection, Toxicology, Environmenta...  2010
# 1    Report No. Detection, Toxicology, Environmenta...  2011
# 2    Report No. Detection, Toxicology, Environmenta...  2009
# 3    Report No. Detection, Toxicology, Environmenta...  2011
# 4    Report No. Detection, Toxicology, Environmenta...  2005
# ..                                                 ...   ...
# 972  Report No.352 Synthesis of Literature and Prel...  2019
# 973  Report No.352 Synthesis of Literature and Prel...  2017
# 974  Report No.352 Synthesis of Literature and Prel...  2018
# 975  Report No.352 Synthesis of Literature and Prel...  2019
# 976  Report No.352 Synthesis of Literature and Prel...  1000
#
# [977 rows x 7 columns]

# %%
#show and delete where Target = NaN
df1 = df1.dropna(subset='Target')

# %% [markdown]
# Report No.352 Synthesis of Literature and Preliminary Modelling Relevant to Society-wide Scenarios for Effective Climate Change Mitigation in Ireland 000Gusenbauer, M., 2019. Google Scholar to overshadow them all? Comparing the sizes of 12 academic search engines and bibliographic databases. Scientometrics 118: 177–214. https://doi.org/10.1007/ s11192-018-2958-5
#
# -------------------
# Target: Google Scholar to overshadow them all
# Target must be: Google Scholar to overshadow them all? Comparing the sizes of 12 academic search engines and bibliographic databases.

# %%
df1["Target_Length"]= df1["Target"].str.len()
# Out:
# <ipython-input-69-a3d65b3fbe79>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["Target_Length"]= df1["Target"].str.len()

# %%
df1
# Out:
#                                                 Source  \
# 0    Report No. Detection, Toxicology, Environmenta...
# 1    Report No. Detection, Toxicology, Environmenta...
# 2    Report No. Detection, Toxicology, Environmenta...
# 3    Report No. Detection, Toxicology, Environmenta...
# 4    Report No. Detection, Toxicology, Environmenta...
# ..                                                 ...
# 971  Report No.352 Synthesis of Literature and Prel...
# 972  Report No.352 Synthesis of Literature and Prel...
# 973  Report No.352 Synthesis of Literature and Prel...
# 974  Report No.352 Synthesis of Literature and Prel...
# 975  Report No.352 Synthesis of Literature and Prel...
#
#                                                 Target  isEPA  \
# 0    Synthesis and applications of  silver nanopart...      0
# 1    Humic  acid-induced silver nanoparticle format...      0
# 2                 History of the medical use of  silve      0
# 3    Synthesis, characterization and antibacterial ...      0
# 4                            Algal Culturing Technique      0
# ..                                                 ...    ...
# 971  Mental maps of the future: an intuitive  logic...      0
# 972                                      World GDP dat      0
# 973  At the last well on Earth: climate change  is ...      0
# 974            Future climate risk from compound event      0
# 975  Climate Action Plan CBA Cost–benefit analysis ...      0
#
#                                                authors  \
# 0    Abou El-Nour, K.M.M.M., Eftaiha, A.A., Al-Wart...
# 1    Akaighe, N., Maccuspie, R.I., Navarro, D.A., A...
# 2                                     Alexander, J.W.,
# 3    Amato, E., Diaz-Fernandez, Y.A., Taglietti, A....
# 4                                      Anderson, R.A.,
# ..                                                 ...
# 971                                        Wilson, I.,
# 972                                        World Bank,
# 973                                        Zoloth, L.,
# 974  Zscheischler, J., Westra, S., van den Hurk, B....
# 975  AD Anaerobic digestion BAU Business as usual C...
#
#                                                  extra  \
# 0            Arabian Journal of Chemistry 3:  135–140.
# 1    Environmental  Science & Technology 45: 3895–3...
# 2                     Surgical infections 10: 289–292.
# 3                              Langmuir 27: 9165–9173.
# 4    Elsevier Academic Press/Phycological Society o...
# ..                                                 ...
# 971  In Fahey, L. and Robert  M Randall, R.M. (eds)...
# 972  Available online:  http://api.worldbank.org/v2...
# 973  Journal of Feminist Studies  in Religion 33: 1...
# 974  Nature Climate Change 8: 469–477. https://doi....
# 975                                                NaN
#
#                                               targetdf  year  Target_Length
# 0    Report No. Detection, Toxicology, Environmenta...  2010             50
# 1    Report No. Detection, Toxicology, Environmenta...  2011             91
# 2    Report No. Detection, Toxicology, Environmenta...  2009             36
# 3    Report No. Detection, Toxicology, Environmenta...  2011            150
# 4    Report No. Detection, Toxicology, Environmenta...  2005             25
# ..                                                 ...   ...            ...
# 971  Report No.352 Synthesis of Literature and Prel...  1998             68
# 972  Report No.352 Synthesis of Literature and Prel...  2019             13
# 973  Report No.352 Synthesis of Literature and Prel...  2017             61
# 974  Report No.352 Synthesis of Literature and Prel...  2018             39
# 975  Report No.352 Synthesis of Literature and Prel...  2019           1553
#
# [976 rows x 8 columns]

# %% [markdown]
# delete all Titles of publications that are shorter than 5 characters or longer then 350 characters
# Usually, it is exactly that rows that were hard to divide into columns correctly.
# So it`s basically cleaning
# But for future it would better to find the way to prepare that data.

# %%
df1.drop(df1.loc[df1['Target_Length']<5].index, inplace=True)
df1.drop(df1.loc[df1['Target_Length']>350].index, inplace=True)
# Out:
# <ipython-input-71-a24cd0e651b6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop(df1.loc[df1['Target_Length']<5].index, inplace=True)
# <ipython-input-71-a24cd0e651b6>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop(df1.loc[df1['Target_Length']>350].index, inplace=True)

# %%
df1
# Out:
#                                                 Source  \
# 0    Report No. Detection, Toxicology, Environmenta...
# 1    Report No. Detection, Toxicology, Environmenta...
# 2    Report No. Detection, Toxicology, Environmenta...
# 3    Report No. Detection, Toxicology, Environmenta...
# 4    Report No. Detection, Toxicology, Environmenta...
# ..                                                 ...
# 970  Report No.352 Synthesis of Literature and Prel...
# 971  Report No.352 Synthesis of Literature and Prel...
# 972  Report No.352 Synthesis of Literature and Prel...
# 973  Report No.352 Synthesis of Literature and Prel...
# 974  Report No.352 Synthesis of Literature and Prel...
#
#                                                 Target  isEPA  \
# 0    Synthesis and applications of  silver nanopart...      0
# 1    Humic  acid-induced silver nanoparticle format...      0
# 2                 History of the medical use of  silve      0
# 3    Synthesis, characterization and antibacterial ...      0
# 4                            Algal Culturing Technique      0
# ..                                                 ...    ...
# 970  Chair’s Final Report – UK Net-Zero  Advisory G...      0
# 971  Mental maps of the future: an intuitive  logic...      0
# 972                                      World GDP dat      0
# 973  At the last well on Earth: climate change  is ...      0
# 974            Future climate risk from compound event      0
#
#                                                authors  \
# 0    Abou El-Nour, K.M.M.M., Eftaiha, A.A., Al-Wart...
# 1    Akaighe, N., Maccuspie, R.I., Navarro, D.A., A...
# 2                                     Alexander, J.W.,
# 3    Amato, E., Diaz-Fernandez, Y.A., Taglietti, A....
# 4                                      Anderson, R.A.,
# ..                                                 ...
# 970                                        Watson, J.,
# 971                                        Wilson, I.,
# 972                                        World Bank,
# 973                                        Zoloth, L.,
# 974  Zscheischler, J., Westra, S., van den Hurk, B....
#
#                                                  extra  \
# 0            Arabian Journal of Chemistry 3:  135–140.
# 1    Environmental  Science & Technology 45: 3895–3...
# 2                     Surgical infections 10: 289–292.
# 3                              Langmuir 27: 9165–9173.
# 4    Elsevier Academic Press/Phycological Society o...
# ..                                                 ...
# 970  UK Net-Zero Advisory Group to the Committee  o...
# 971  In Fahey, L. and Robert  M Randall, R.M. (eds)...
# 972  Available online:  http://api.worldbank.org/v2...
# 973  Journal of Feminist Studies  in Religion 33: 1...
# 974  Nature Climate Change 8: 469–477. https://doi....
#
#                                               targetdf  year  Target_Length
# 0    Report No. Detection, Toxicology, Environmenta...  2010             50
# 1    Report No. Detection, Toxicology, Environmenta...  2011             91
# 2    Report No. Detection, Toxicology, Environmenta...  2009             36
# 3    Report No. Detection, Toxicology, Environmenta...  2011            150
# 4    Report No. Detection, Toxicology, Environmenta...  2005             25
# ..                                                 ...   ...            ...
# 970  Report No.352 Synthesis of Literature and Prel...  2019             84
# 971  Report No.352 Synthesis of Literature and Prel...  1998             68
# 972  Report No.352 Synthesis of Literature and Prel...  2019             13
# 973  Report No.352 Synthesis of Literature and Prel...  2017             61
# 974  Report No.352 Synthesis of Literature and Prel...  2018             39
#
# [965 rows x 8 columns]

# %% [markdown]
# ##4 Creating dynamic graph to show many old or new sources are used

# %%
#convert year to data year and sort by year

# %%
df1.to_csv('21082023citation_test_dataset.csv',encoding='utf-8-sig', header=df1.columns)

# %%
df1['year'].unique()
# Out:
# array(['2010', '2011', '2009', '2005', '2013', '2014', '2012', '2008',
#        '2015', '2016', '2006', '2017', '2018', '2002', '2007', '1996',
#        '2001', '2019', '1997', '1998', '2020', '1992', '1995', '1991',
#        '2000', '2003', '1942', '1972', '1976', '1999', '2004', '1904',
#        '2021', '2022', '1973', '2030', '1983', '1990', '1921', '1993'],
#       dtype=object)

# %%
df1['Source'].unique()
# Out:
# array(['Report No. Detection, Toxicology, Environmental Fate \nand Risk Assessment of Nanoparticles in the  Aquatic Environment (DeTER)',
#        'Report No.346 National Risk Assessment of \nImpacts of Climate Change: Bridging  the Gap to Adaptation Action',
#        'Report No.  Building Coastal and Marine \nResilience in Ireland',
#        'Report No.369 CIViC: Critical \nInfrastructure Vulnerability  to Climate Change',
#        'Report No.362 Evaluating Ireland’s Climate \nPolicy Performance',
#        'Report No.360 Methodologies for Financing and Costing \nof Climate Impacts and Future Adaptation  Actions: Transport Networks in Ireland',
#        'Report No.357 Ireland’s Atmospheric Composition \nand Climate Change Network',
#        'Report No.352 Synthesis of Literature and Preliminary Modelling\nRelevant to Society-wide Scenarios for Effective Climate Change Mitigation in Ireland'],
#       dtype=object)
